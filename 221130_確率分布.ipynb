# %% [markdown]
# ### ライブラリのimport

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 確率分布

# %%
# 離散一様分布
# random variates(rvs): 確率変量(実現値？)
stats.randint.rvs(1, 7)
# Out:
# 4

# %%
stats.randint(1, 7).rvs()
# Out:
# 2

# %%
stats.randint.mean(1, 7) # 期待値
# Out:
# 3.5

# %%
# 連続一様分布
stats.uniform.rvs(0, 1)
# Out:
# 0.9498712595950105

# %%
stats.uniform(0, 1).rvs()
# Out:
# 0.4924205748122702

# %% [markdown]
# ### 確率分布の描画

# %%
def simple_func(x):
    return x**2 + 3

# %%
simple_func(10)
# Out:
# 103

# %%
x = np.linspace(-3, 3, 100)
y = simple_func(x)

# %%
plt.plot(x, y)

# %%
x = np.arange(-3, 4)
y = simple_func(x)

# %%
plt.plot(x, y)

# %%
x = np.arange(1, 7)
y = stats.randint(1, 7).pmf(x)
plt.plot(x, y, 'o')
plt.vlines(x, ymin=0, ymax=y)

# %%
x = np.linspace(-2, 2, 100)
y = stats.uniform(loc=0, scale=1).pdf(x)
plt.plot(x, y)

# %% [markdown]
# ### 累積分布関数(CDF)

# %%
x = np.linspace(-3, 3, 100)
y = stats.norm.pdf(x)
plt.plot(x, y)

# %%
x = np.linspace(-3, 3, 100)
y = stats.norm.cdf(x)
plt.plot(x, y)

# %%
# Survival Function
x = np.linspace(-3, 3, 100)
y = stats.norm.sf(x)
plt.plot(x, y)

# %% [markdown]
# ### 正規分布

# %%
# normal distribution
stats.norm(loc=10, scale=3).rvs()
# Out:
# 12.27067841887394

# %%
x = np.linspace(-5, 15, 100)
y = stats.norm(loc=10, scale=3).pdf(x)
y2 = stats.norm(loc=8, scale=3).pdf(x)
y3 = stats.norm(loc=8, scale=1).pdf(x)
plt.plot(x,y)
plt.plot(x,y2)
plt.plot(x,y3)

# %%
# 引数を指定しないと標準正規分布になる
y = stats.norm.pdf(x)
plt.plot(x, y)

# %% [markdown]
# ### カーネル密度推定(KDE: Kernel Density Estimation)

# %%
x = np.linspace(-3, 10, 100)
y = stats.gaussian_kde([1, 1, 2, 2, 3, 4, 5]).pdf(x)
plt.plot(x, y)

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x = np.linspace(-3, 10, 100)
y = stats.gaussian_kde(df['tip']).pdf(x)
plt.plot(x, y)

# %%
sns.displot(df['tip'], kde=True)

# %%
resample_data = stats.gaussian_kde(df['tip']).resample()
resample_data
# Out:
# array([[ 6.72189065,  0.52192837,  2.06964919,  3.61560555,  5.81561908,
#         -0.08662526,  0.40128344,  4.0139669 ,  4.17111728,  1.20961318,
#          6.00066503,  1.42092952,  3.95444472,  2.20113394,  2.09839257,
#          5.49778323,  3.68226961,  3.22162115,  3.41355328,  1.69817324,
#          1.51408277,  2.10590977,  2.32702958,  2.83176193,  3.91399907,
#          1.53859216,  2.97776164,  2.64501254,  2.86496195,  3.62712727,
#          2.12860593,  2.41741145,  2.01085304,  2.744871  ,  1.89560309,
#          2.10806157,  2.66122796,  2.61900897,  1.53832893,  3.79543045,
#          1.05246552,  3.11591469,  1.657913  ,  2.84440706,  1.78914156,
